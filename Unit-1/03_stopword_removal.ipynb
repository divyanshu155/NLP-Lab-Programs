# %% [markdown]
# <a href="https://colab.research.google.com/github/divyanshu155/NLP-Lab-Programs/blob/main/Unit-1/03_stopword_removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")

from nltk.corpus import stopwords

text = "This is a simple document for demonstrating stop word removal."

words = nltk.word_tokenize(text)

stop_words = set(stopwords.words("english"))

filtered_words = []

for word in words:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("Original Text:")
print(text)

print("\nAfter Stop-word Removal:")
print(filtered_words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Original Text:
# This is a simple document for demonstrating stop word removal.
#
# After Stop-word Removal:
# ['simple', 'document', 'demonstrating', 'stop', 'word', 'removal', '.']
